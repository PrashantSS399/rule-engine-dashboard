# %%
# %run Functions.ipynb

# %%
# %run Dataset.ipynb
# Out:
# Connection successful!
# PostgreSQL 17.5 on x86_64-windows, compiled by msvc-19.43.34808, 64-bit

# %%
customers
# Out:
#     id customer_id               name        dob  \
# 0    1    CUST_001        Rohan Mehta 1992-05-16
# 1    2    CUST_001        Rohan Mehta 1992-05-16
# 2    3    CUST_001        Rohan Mehta 1992-05-16
# 3    4    CUST_002       Priya Sharma 1988-09-22
# 4    5    CUST_002       Priya Sharma 1988-09-22
# 5    6    CUST_003        Arjun Reddy 1995-03-10
# 6    7    CUST_004        Neha Kapoor 1990-12-05
# 7    8    CUST_004        Neha Kapoor 1990-12-05
# 8    9    CUST_005        Amitabh Das 1985-07-18
# 9   10    CUST_006       Ananya Patel 1993-04-12
# 10  11    CUST_006       Ananya Patel 1993-04-12
# 11  12    CUST_007       Vikram Singh 1987-11-30
# 12  13    CUST_008         Meera Nair 1991-08-25
# 13  14    CUST_008         Meera Nair 1991-08-25
# 14  15    CUST_009        Rahul Verma 1989-02-14
# 15  16    CUST_010        Sneha Gupta 1994-07-08
# 16  17    CUST_011       Karthik Iyer 1990-10-03
# 17  18    CUST_011       Karthik Iyer 1990-10-03
# ...

# %%
accounts
# Out:
#      account_no account_type customer_id account_status activation_date
# 0   20001234567      Savings    CUST_001         Active      2021-01-15
# 1   20004578624      Current    CUST_001       Inactive      2019-05-22
# 2   20001498732        Demat    CUST_001         Active      2015-11-09
# 3   20002534697      Current    CUST_002         Active      2017-07-19
# 4   20009876543      Savings    CUST_002      Suspended      2023-02-15
# 5   20005678901      Savings    CUST_003         Active      2022-08-11
# 6   20008774153        Demat    CUST_004         Active      2024-04-03
# 7   20002345678      Current    CUST_004       Inactive      2022-06-18
# 8   20007890123      Savings    CUST_005         Active      2025-10-14
# 9   20001112233      Savings    CUST_006         Active      2020-03-12
# 10  20002223344      Current    CUST_006       Inactive      2018-07-25
# 11  20003334455      Savings    CUST_007         Active      2021-09-08
# ...

# %%
transactions
# Out:
#     transaction_id   account_no customer_id    amount    transaction_time
# 0                1  20001234567    CUST_001  185000.0 2025-05-10 10:15:00
# 1                2  20004578624    CUST_001  -15000.0 2022-12-11 11:30:00
# 2                3  20001498732    CUST_001  -22000.0 2023-12-11 14:00:00
# 3                4  20002534697    CUST_002   15000.0 2025-01-05 15:45:00
# 4                5  20009876543    CUST_002   25000.0 2023-04-05 16:40:00
# 5                6  20005678901    CUST_003   65000.0 2024-02-18 11:00:00
# 6                7  20005678901    CUST_003  -16000.0 2023-09-22 13:25:00
# 7                8  20008774153    CUST_004   40000.0 2024-03-22 14:20:00
# 8                9  20002345678    CUST_004  -18000.0 2023-11-22 17:15:00
# 9               10  20007890123    CUST_005  100000.0 2024-04-10 09:00:00
# 10              11  20001112233    CUST_006  120000.0 2025-04-05 09:30:00
# 11              12  20002223344    CUST_006   -8000.0 2023-11-15 10:45:00
# ...
